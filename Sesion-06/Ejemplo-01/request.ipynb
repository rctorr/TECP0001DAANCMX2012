# %% [markdown]
# ## Ejemplo 1: Usando la librería Requests
#
# ### 1. Objetivos:
#     - Aprender a usar la librería Requests para hacer peticiones HTTP
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Instalación:

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/rctorr/miniconda3/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/rctorr/miniconda3/lib/python3.7/site-packages (from requests) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/rctorr/miniconda3/lib/python3.7/site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rctorr/miniconda3/lib/python3.7/site-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/rctorr/miniconda3/lib/python3.7/site-packages (from requests) (3.0.4)

# %% [markdown]
# Importando los módulos necesarios

# %%
import pandas as pd
import requests

# %% [markdown]
# Vamos a hacer peticiones a una api de la NASA que ofrece datos sobre objetos que orbitan cerca de la Tierra. Pueden ver la documentación [aquí](https://api.nasa.gov/). Ahí podemos ver los puntos finales o de peticiones (endpoints) y la manera en la que se usa la Api Key. Ve a la página y consigue tu propia Api Key para que puedas realizar los ejercicios.

# %% [markdown]
# Ahora, para empezar, necesitamos nuestro url del punto final y nuestro diccionario con los parámetros de acceso.

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {'api_key': 'EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'}

# %% [markdown]
# Ambos se los pasamos al método `GET` de `requests` para realizar la petición y enviar los parámetros como información extra que el API necesita usando la forma:
#
# `requests.get(-url del punto final-, params=-dict con parámetros-)`

# %%
resultado =

# %% [markdown]
# Ahora, podemos leer el estado de la respuesta usando:
#
# `mi_requests.status_code`

# %%
# tu código
# Out:
# 200

# %% [markdown]
# Ahora veamos los datos incluídos en la respuesta en formato json usando el método `mi_requests.json()`:

# %%
# tu código

# %% [markdown]
# ¡Esa es una respuesta muy larga! Vamos a diseccionarla, promero hay que conocer cuales son las llaves en el diccionario u objeto de json con el método:
#
# `mi_requests.json().keys()`
#
# Podemos aplicar el método `.heys()` porque `.json()` regresa un diccionario, capichi!

# %%
# tu código
# Out:
# dict_keys(['links', 'page', 'near_earth_objects'])

# %% [markdown]
# Que hay en `links`:

# %%
datos_dict = resultado.json()
# tu código
# Out:
# {'next': 'http://www.neowsapp.com/rest/v1/neo/browse?page=1&size=20&api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5',
#  'self': 'http://www.neowsapp.com/rest/v1/neo/browse?page=0&size=20&api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'}

# %% [markdown]
# Que hay en `page`:

# %%
# tu código
# Out:
# {'size': 20, 'total_elements': 24156, 'total_pages': 1208, 'number': 0}

# %% [markdown]
# Que hay en `near_earth_objects`:

# %%
# tu código
# Out:
# {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2021277?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#  'id': '2021277',
#  'neo_reference_id': '2021277',
#  'name': '21277 (1996 TO5)',
#  'designation': '21277',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2021277',
#  'absolute_magnitude_h': 16.1,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.6016033798,
#    'estimated_diameter_max': 3.5812940302},
#   'meters': {'estimated_diameter_min': 1601.6033797856,
#    'estimated_diameter_max': 3581.2940301941},
#   'miles': {'estimated_diameter_min': 0.9951898937,
#    'estimated_diameter_max': 2.2253122528},
#   'feet': {'estimated_diameter_min': 5254.6044325359,
#    'estimated_diameter_max': 11749.652706022}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '1945-06-07',
#    'close_approach_date_full': '1945-Jun-07 22:35',
#    'epoch_date_close_approach': -775272300000,
#    'relative_velocity': {'kilometers_per_second': '15.509475255',
#     'kilometers_per_hour': '55834.1109179878',
#     'miles_per_hour': '34693.1451979019'},
#    'miss_distance': {'astronomical': '0.0334232931',
#     'lunar': '13.0016610159',
#     'kilometers': '5000053.456145697',
#     'miles': '3106889.1492847386'},
#    'orbiting_body': 'Mars'}],
#  'orbital_data': {'orbit_id': '165',
#   'orbit_determination_date': '2020-08-02 06:25:53',
#   'first_observation_date': '1990-02-04',
#   'last_observation_date': '2020-05-13',
#   'data_arc_in_days': 11056,
#   'observations_used': 659,
#   'orbit_uncertainty': '0',
#   'minimum_orbit_intersection': '.313031',
#   'jupiter_tisserand_invariant': '3.267',
#   'epoch_osculation': '2459000.5',
#   'eccentricity': '.5205881328788736',
#   'semi_major_axis': '2.376601474329985',
#   'inclination': '20.9522649964117',
#   'ascending_node_longitude': '167.3841289832412',
#   'orbital_period': '1338.236805731597',
#   'perihelion_distance': '1.13937095021136',
#   'perihelion_argument': '250.1729632865032',
#   'aphelion_distance': '3.613831998448611',
#   'perihelion_time': '2458492.539291811604',
#   'mean_anomaly': '136.6468581379752',
#   'mean_motion': '.2690106851479045',
#   'equinox': 'J2000',
#   'orbit_class': {'orbit_class_type': 'AMO',
#    'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#    'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#  'is_sentry_object': False}

# %% [markdown]
# Guardemos la lista de objetos en la variable `objetos` y veamos sólo el primero:

# %%
# tu código
# Out:
# {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2021277?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#  'id': '2021277',
#  'neo_reference_id': '2021277',
#  'name': '21277 (1996 TO5)',
#  'designation': '21277',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2021277',
#  'absolute_magnitude_h': 16.1,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.6016033798,
#    'estimated_diameter_max': 3.5812940302},
#   'meters': {'estimated_diameter_min': 1601.6033797856,
#    'estimated_diameter_max': 3581.2940301941},
#   'miles': {'estimated_diameter_min': 0.9951898937,
#    'estimated_diameter_max': 2.2253122528},
#   'feet': {'estimated_diameter_min': 5254.6044325359,
#    'estimated_diameter_max': 11749.652706022}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '1945-06-07',
#    'close_approach_date_full': '1945-Jun-07 22:35',
#    'epoch_date_close_approach': -775272300000,
#    'relative_velocity': {'kilometers_per_second': '15.509475255',
#     'kilometers_per_hour': '55834.1109179878',
#     'miles_per_hour': '34693.1451979019'},
#    'miss_distance': {'astronomical': '0.0334232931',
#     'lunar': '13.0016610159',
#     'kilometers': '5000053.456145697',
#     'miles': '3106889.1492847386'},
#    'orbiting_body': 'Mars'}],
#  'orbital_data': {'orbit_id': '165',
#   'orbit_determination_date': '2020-08-02 06:25:53',
#   'first_observation_date': '1990-02-04',
#   'last_observation_date': '2020-05-13',
#   'data_arc_in_days': 11056,
#   'observations_used': 659,
#   'orbit_uncertainty': '0',
#   'minimum_orbit_intersection': '.313031',
#   'jupiter_tisserand_invariant': '3.267',
#   'epoch_osculation': '2459000.5',
#   'eccentricity': '.5205881328788736',
#   'semi_major_axis': '2.376601474329985',
#   'inclination': '20.9522649964117',
#   'ascending_node_longitude': '167.3841289832412',
#   'orbital_period': '1338.236805731597',
#   'perihelion_distance': '1.13937095021136',
#   'perihelion_argument': '250.1729632865032',
#   'aphelion_distance': '3.613831998448611',
#   'perihelion_time': '2458492.539291811604',
#   'mean_anomaly': '136.6468581379752',
#   'mean_motion': '.2690106851479045',
#   'equinox': 'J2000',
#   'orbit_class': {'orbit_class_type': 'AMO',
#    'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#    'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#  'is_sentry_object': False}

# %% [markdown]
# `links` y `page` son metadata que vamos a utilizar luego para automatizar el proceso de peticiones. `objetos` es una lista de diccionarios que contiene los datos que queremos utilizar.
#
# Vamos a convertirlos en un `DataFrame` aplicando un proceso de normalización que consiste en acomodar la información por columnas usando:
#
# `pd.json_normalize(-objetos_dict-)`
#
# esto nos regresa un nuevo diccionario que ahora si puede ser usado para crear el `DataFrame` con:
#
# `pd.DataFrame(-objectos_dict_normalizados-)`

# %%
# normaliza
normalizados = 
# convierte a DataFrame
df =
# examina
df.head()
# Out:
#         id neo_reference_id                name designation  \
# 0  2021277          2021277    21277 (1996 TO5)       21277
# 1  2162038          2162038    162038 (1996 DH)      162038
# 2  2189058          2189058  189058 (2000 UT16)      189058
# 3  2276274          2276274  276274 (2002 SS41)      276274
# 4  2322913          2322913   322913 (2002 CM1)      322913
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2021277                  16.1
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2162038                  16.6
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2189058                  16.5
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2276274                  17.2
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2322913                  16.7
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '1945-06-07', 'close_...             False
# 1                                                 []             False
# 2                                                 []             False
# 3                                                 []             False
# 4                                                 []             False
#
#                                           links.self  ...  \
# 0  http://www.neowsapp.com/rest/v1/neo/2021277?ap...  ...
# 1  http://www.neowsapp.com/rest/v1/neo/2162038?ap...  ...
# 2  http://www.neowsapp.com/rest/v1/neo/2189058?ap...  ...
# 3  http://www.neowsapp.com/rest/v1/neo/2276274?ap...  ...
# 4  http://www.neowsapp.com/rest/v1/neo/2322913?ap...  ...
#
#    orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0               3.613831998448611          2458492.539291811604
# 1               2.025868401292677          2459176.565269603596
# 2               3.884205425293149          2459278.734073290831
# 3               2.910206356306218          2459093.016755001286
# 4               3.361558630853122          2458482.209254870466
#
#    orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0          136.6468581379752         .2690106851479045                 J2000
# 1          273.1861301006437         .4930777665283681                 J2000
# 2          293.4095329628478         .2393325384254674                 J2000
# 3          330.1368353787589          .322786554941599                 J2000
# 4          146.5048635106909         .2826692640905165                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        AMO
# 1                                        AMO
# 2                                        AMO
# 3                                        AMO
# 4                                        AMO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits similar to that of ...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
# 3  Near-Earth asteroid orbits similar to that of ...
# 4  Near-Earth asteroid orbits similar to that of ...
#
#    orbital_data.orbit_class.orbit_class_range name_limited sentry_data
# 0          1.017 AU < q (perihelion) < 1.3 AU          NaN         NaN
# 1          1.017 AU < q (perihelion) < 1.3 AU          NaN         NaN
# 2          1.017 AU < q (perihelion) < 1.3 AU          NaN         NaN
# 3          1.017 AU < q (perihelion) < 1.3 AU          NaN         NaN
# 4          1.017 AU < q (perihelion) < 1.3 AU          NaN         NaN
#
# [5 rows x 45 columns]

# %%
# dimensiones del DataFrame
# Out:
# (20, 45)

# %% [markdown]
# ¡Listo! Ahora tenemos un `DataFrame` con los datos de nuestra primera petición. En esta sesión vamos a aprender a automatizar este proceso. Pero antes, practiquemos un poco el uso de la librería `requests`.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 1: Peticiones a una API usando requests
#
# ### 1. Objetivos:
#     - Usar la librería Requests para hacer una petición HTTP a una API
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# ### a) Petición HTTP a API de NASA
#
# Vamos a implementar un programa que realice una llamada HTTP a la API de NASA.
#
# Puedes leer la documentación de la API [aquí](https://api.nasa.gov/), bajo el título de "Asteroids NeoWs".

# %%
# imports necesarios

# %% [markdown]
# Tu reto consiste en los siguientes pasos:
#
# 1. Crea una cuenta en el API de NASA para obtener tu propia API Key. Copia la API Key en la celda debajo para que no la pierdas:

# %%
api_key = ""

# %% [markdown]
# 2. Asigna la variable `url` -donde tendrás el URL base de la API de NASA- y la variable `parametros` -donde tendrás el diccionario que usarás para pasar parámetros a tu petición.
#
# 3. Usa tu diccionario `parametros` para agregar los parámetros necesarios para pedir la hoja número 100 de la API. Durante el ejemplo, pedimos simplemente la primera hoja. En esta ocasión, debes de descubrir que parámetros requieres pasarle para obtener la hoja #100. Además queremos que el número de resultados que nos regresen sea menor al default. El default es 20, pero tú tienes que mandar los parámetros adecuados para que te regresen solamente 5 resultados

# %%
url = ''
parametros = {}

# %% [markdown]
# 4. Realiza tu petición HTTP aquí debajo y checa tu código de respuesta para asegurarte de que la petición se haya hecho exitosamente:

# %%
# tu código para la petición

# %%
# tu código para obtener el código

# %% [markdown]
# 5. Si todo ha salido bien, extrae tus datos, normalízalos, crea un `DataFrame` con ellos y asígnalo a `objetos`. Revisa que solamente tengas 5 filas, para saber que tu petición se realizó exitosamente:

# %%
datos = 
objetos = 
normalizados = 
df = 
df
